# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
#"C:\Users\asus\CareerFoundry\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl"
path = r'C:\Users\asus\CareerFoundry\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
ords_prods_merge.head(50)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
#df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']}
#df.groupby('department_id')['order_number'].mean()
ords_prods_merge.groupby('department_id')[['order_number','orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order', 'product_id', 'add_to_cart_order', 'aisle_id', 'prices']].mean()
# Out:
#                order_number  orders_day_of_week  order_hour_of_day  \
# department_id
# 1                 15.457838            2.790508          13.681669
# 2                 17.277920            2.851368          13.498939
# 3                 17.170395            2.743055          13.398569
# 4                 17.811403            2.683672          13.424949
# 5                 15.215751            3.163153          13.594264
# 6                 16.439806            2.691937          13.518913
# 7                 17.225802            2.807199          13.314115
# 8                 15.340650            2.934893          13.578544
# 9                 15.895474            2.690505          13.546041
# 10                20.197148            2.759061          13.458537
# 11                16.170638            2.816660          13.486800
# 12                15.887671            2.718082          13.468507
# 13                16.583536            2.810497          13.458808
# ...

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## The subset differs from the entire dataframe becuase it is just one number per department and that number is the average

# %%
ords_prods_merge.groupby('loyalty_flag')[['order_number','orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order', 'product_id', 'add_to_cart_order', 'aisle_id', 'prices']].mean()
# Out:
#                   order_number  orders_day_of_week  order_hour_of_day  \
# loyalty_flag
# Loyal customer       32.641196            2.791642          13.188346
# New customer          3.807044            2.697449          13.673824
# Regular customer     12.347452            2.720970          13.480738
#
#                   days_since_prior_order    product_id  add_to_cart_order  \
# loyalty_flag
# Loyal customer                  6.026656  25580.887946           8.284024
# New customer                   17.976936  25620.003822           8.268989
# Regular customer               12.155135  25601.781240           8.429793
#
#                    aisle_id     prices
# loyalty_flag
# Loyal customer    71.148742  10.386336
# New customer      71.320477  13.294670
# Regular customer  71.177894  12.495717

# %% [markdown]
# # Spending Flag

# %%
#ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge['mean_order'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['mean_order'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['mean_order'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# # Frequency Flag

# %%
ords_prods_merge['Median_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
#If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
ords_prods_merge.loc[ords_prods_merge['Median_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['Median_frequency'] > 10) & (ords_prods_merge['Median_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['Median_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
#ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
